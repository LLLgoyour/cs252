# %% [markdown]
# # CS251/2: Data Analysis and Visualization
#
# ## Polynomial Regression Examples and Applications
#
# Spring 2026
#
# Oliver W. Layton

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
import data

# %% [markdown]
# ## Load in Boston Housing data
#
# CSV filename: `boston.csv`

# %%
with open("data/boston.csv", "r") as
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 with open("data/boston.csv", "r") as f:
# ----> 2     data = data.Data(f)
#
# AttributeError: module 'data' has no attribute 'Data'

# %% [markdown]
# Info on the headers:
#
#     CRIM - per capita crime rate by town
#     ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#     INDUS - proportion of non-retail business acres per town.
#     CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#     NOX - nitric oxides concentration (parts per 10 million)
#     RM - average number of rooms per dwelling
#     AGE - proportion of owner-occupied units built prior to 1940
#     DIS - weighted distances to five Boston employment centres
#     RAD - index of accessibility to radial highways
#     TAX - full-value property-tax rate per 10,000 dollars
#     PTRATIO - pupil-teacher ratio by town
#     LSTAT - % lower status of the population
#     MEDV - Median value of owner-occupied homes in 1000's dollars

# %% [markdown]
# ## Perform linear regression to predict median home value from distance to workplace hubs
#
# Independent and dependent variables?
#
# Let's make a scatterplot of the data.

# %%
plt.xlabel('Distance from workplace hubs')
plt.ylabel('Home value')
plt.show()

# %% [markdown]
# ### Try Quadratic polynomial regression model to fit the nonlinear relationship:
#
# $$y = c_0 + c_1x_1 + c_2x_1^2$$
#
# where $x_1$ is what?

# %%
N = len(x)
A = np.hstack([np.ones([N, 2]), x, x**2])

# %%
x_line = np.linspace(np.min(x), np.max(x))
y_line = c[0] + c[1]*x_line + c[2]*x_line**2
plt.xlabel('Distance from workplace hubs')
plt.ylabel('Home value')
plt.show()

# %% [markdown]
# ### Now let's try a cubic model
#
# $$y = c_0 + c_1x_1 + c_2x_1^2 + c_3x_1^3$$

# %%
plt.xlabel('Distance from workplace hubs')
plt.ylabel('Home value')
plt.show()
