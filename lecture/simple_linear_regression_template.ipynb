# %% [markdown]
# # CS252: Mathematical Data Analysis and Visualization
#
# ## Using SciPy's Least Squares Solver to perform Linear Regression
#
# Spring 2026
#
# Oliver W. Layton

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

np.set_printoptions(suppress=True)

# %%
from data import Data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from data import Data
#
# ImportError: cannot import name 'Data' from 'data' (unknown location)

# %% [markdown]
# ## 1. Predict temperature in fahrenheit from celsius
#
# Let's see how the linear regression fitting process plays out with a familiar example:
#
# Can we predict the temperature value in fahrenheit from the value in celsius?

# %% [markdown]
# Load in Temperature dataset
#
# CSV filename: `temps.csv`

# %%
with open(temps.csv, 'f')

# %% [markdown]
# What is our independent variable?

# %%
#

# %% [markdown]
# What is our dependent variable?

# %%
#

# %% [markdown]
# The linear regression equation is: $$A\vec{c} = \vec{y}$$
#
# Let's setup:
#
# - `A` data matrix.
# - `y` dependent variable column vector

# %% [markdown]
# Let's add an intercept to the data matrix, consistent with the linear regression model:
#
# $$y = c_0 + c_1x_1$$
#
# where $x_1$ is the temp of each sample in Celsius.

# %%
A = np.hstack([np.ones])

# %% [markdown]
# Let's use SciPy's least squares solver to determine the unknown intercept $c_0$ and slope $c_1$ coefficient for us.

# %% [markdown]
# Let's look at the coefficients. Remember that the equation to convert Celsius to Fahrenheit is:
#
# $$
# F = (9/5)C + 32
# $$

# %%
print()
print()

# %% [markdown]
# Let's draw the regression line! We need:
#
# - Evenly spaced sample points between the min and max independent variable values in the dataset ("x")
# - **Predicted** dependent variable values according to the fitted regression model (using the coefficients we solved for with SciPy).

# %%
x_line = np.linspace(np.min(x), np.max(x))
y_line = c[0] + c[1]*x

# %%
plt.scatter(x,y)
plt.plot(x_line, y_line, c = 'r')
plt.xlabel('Temp Celsius (°)')
plt.ylabel('Temp Fahrenheit (°)')
plt.show()

# %% [markdown]
# Now let's discuss how we can quantify the quality with which the linear regression curve fits the data.
