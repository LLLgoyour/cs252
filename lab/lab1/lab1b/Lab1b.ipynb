# %% [markdown]
# # Lab 1b: Introduction to Jupyter, NumPy, and Matplotlib
#
# ## Task 0: Introduction to Jupyter Notebook
#
# ### Jupyter Notebook Basics
#
# 1. Create your first notebook.
# 1. Click on the Home tab in your web browser with the list of files in the Lab1b directory.
# 1. In the upper right corner, click "New" then "Notebook" then select a "Python 3" kernel in the new browser tab that opens up.
#    <img src="images/lab1b_new_nb_1.png" alt="new notebook 1/2" width="600"/><br/>
#    <img src="images/lab1b_new_nb_2.png" alt="new notebook 2/2" width="300"/>
#
# 1. Click on Untitled at the top left of the notebook and rename your notebook Lab1bTest
# 1. In your first Cell type `## Hello World` and press Run (`Shift+Enter`).
# 1. Change your first cell type to markdown and press Run (`Shift+Enter`).
# 1. [Markdown quick reference](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
# 1. Create a new cell and type `print("Hello World")` into it and press Run (`Shift+Enter`).
# 1. Include "Lab1bTest" in your submission.
#
# <img src="images/bar.png" alt="heading"/>
#
# ## Task 1: Introduction to NumPy
#
# For Tasks 1 and 2 please complete them by editing a copy of this notebook.
#
# ### 1a) Create a NumPy Array
#
# 1. Import `test.csv` located in the Lab1b data subfolder into a ndarray using [NumPy genfromtxt](https://numpy.org/devdocs/reference/generated/numpy.genfromtxt.html), [More info](https://numpy.org/devdocs/user/basics.io.genfromtxt.html)
#    1. You will need to specify the file path and indicate that the delimiter is a comma (the ',' character).
# 2. Print data [printing arrays](https://numpy.org/doc/stable/user/quickstart.html#printing-arrays)

# %%
import numpy as np

# %%
### BEGIN SOLUTION
data = np.genfromtxt('data/test.csv', delimiter=",")
print(data)


### END SOLUTION

#Expected output
#[[15. 16.  4.  5.]
# [ 4. 10. 10.  3.]
# [10.  4. 17. 12.]
# [ 6. 12.  1. 16.]
# [14. 15.  1. 12.]
# [11. 15. 19.  2.]]
# Out:
# [[15. 16.  4.  5.]
#  [ 4. 10. 10.  3.]
#  [10.  4. 17. 12.]
#  [ 6. 12.  1. 16.]
#  [14. 15.  1. 12.]
#  [11. 15. 19.  2.]]

# %% [markdown]
# ### 1b. Explore NumPy array
#
# #### Using the below links ↓ and NumPy documentation to complete the following tasks:
#
# [NumPy ndarray](https://numpy.org/devdocs/reference/arrays.ndarray.html)
# [Array indexing](https://numpy.org/devdocs/user/basics.indexing.html)
#
# 1. Print the shape of the array from test.csv.
# 2. Print just the 3rd column (column with index 2) of the array from test.csv.
# 3. Print just the 5th row of the array from test.csv.
# 4. Use a single ndarray method find the min of each column of the array from test.csv and print it
# 5. Use a single ndarray method to find the max of each row of the array from test.csv and print it
# 6. Use a single ndarray method to find the mean of each column of the array from test.csv and print it
# 7. Use a single ndarray method to find the sum of each row of the array from test.csv and print it
# 8. What is the shape of array2?
# 9. In one line use a ndarray method to convert array2 to a two dimensional array (i.e. remove the **singleton dimension** — the dimension that only has a "1 shape").

# %%
# 1. Print the shape of the array from test.csv.

### BEGIN SOLUTION
data.shape


### END SOLUTION

#Expected output
# (6, 4)
# Out:
# (6, 4)

# %%
# 2. Print just the 3rd column (column with index 2) of the array from test.csv.

### BEGIN SOLUTION
print(data[:,2])


### END SOLUTION

#Expected output
# [ 4. 10. 17.  1.  1. 19.]
# Out:
# [ 4. 10. 17.  1.  1. 19.]

# %%
# 3. Print just the 5th row of the array from test.csv.

### BEGIN SOLUTION

print(data[4])

### END SOLUTION

#Expected output
# [14. 15.  1. 12.]
# Out:
# [14. 15.  1. 12.]

# %%
# 4. Use a single ndarray method find the min of each column of the array from test.csv and print it

### BEGIN SOLUTION

print(np.min(data,axis = 0))

### END SOLUTION

#Expected output
# [4. 4. 1. 2.]
# Out:
# [4. 4. 1. 2.]

# %%
# 5. Use a single ndarray method to find the max of each row of the array from test.csv and print it

### BEGIN SOLUTION

print(np.max(data, axis = 1))

### END SOLUTION

#Expected output
# [16. 10. 17. 16. 15. 19.]
# Out:
# [16. 10. 17. 16. 15. 19.]

# %%
# 6. Use a single ndarray method to find the mean of each column of the array from test.csv and print it

### BEGIN SOLUTION

print(np.mean(data, axis = 0))

### END SOLUTION

#Expected output
# [10.         12.          8.66666667  8.33333333]
# Out:
# [10.         12.          8.66666667  8.33333333]

# %%
# 7. Use a single ndarray method to find the sum of each row of the array from test.csv and print it

### BEGIN SOLUTION

print(np.sum(data, axis = 1))

### END SOLUTION

#Expected output
# [40. 27. 43. 35. 42. 47.]
# Out:
# [40. 27. 43. 35. 42. 47.]

# %%
#array2 given
array2 = np.array([[[0], [2], [4]],[[1], [3], [5]]])

# %%
# 8. What is the shape of array2?

### BEGIN SOLUTION

print(array2.shape)

### END SOLUTION

#Expected output
# (2, 3, 1)
# Out:
# (2, 3, 1)

# %%
# 9. In one line use a ndarray method to convert array2 to a two dimensional array 
#    (i.e. remove the singleton dimension — the dimension that only has a "1 shape").

### BEGIN SOLUTION

array2_squeezed = np.squeeze(array2)
print(array2_squeezed.shape)

### END SOLUTION

#Expected output
# (2, 3)
# Out:
# (2, 3)

# %% [markdown]
# ## Task 2: Matplotlib Basics
#
# **Let me know when you reach this point.**
#
# ### 2a. Plot the data in a single plot
#
# Using the [Matplotlib](https://matplotlib.org/) documentation, visualize the dataset with Matplotlib. All charts should include a title, axis labels and a legend when applicable.
#
# 1. Import `lab1.csv` into a ndarray using genfromtxt.
# 2. Set figure size to 12x8. Use either [plt.figure](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html) or [rcParams](https://matplotlib.org/3.1.0/tutorials/introductory/customizing.html#matplotlib-rcparams) (_search for `figure.figsize`_).
# 3. Create a cartesian line graph of last column (on the X axis) vs the 2nd column (Y axis) using a red dashed line. [matplotlib.pyplot introduction](https://matplotlib.org/tutorials/introductory/pyplot.html)
#    1. Include a title and axis labels.

# %%
### BEGIN SOLUTION
import matplotlib.pyplot as plt
mdata = np.genfromtxt("data/lab1.csv", delimiter=",")
plt.figure(figsize=(12,8))
plt.plot(mdata[:,-1],mdata[:,1],'r--')
plt.xlabel("x")
plt.ylabel("y")
plt.title("plot")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'plot')

# %% [markdown]
# ### 2b. Plot the data in multiple subplots
#
# Create 6 graphs in 2 columns and 3 rows using [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html).
#
# 1. Row 1 is two subplots (a scatterplot and a line graph) of the 2nd column graphed on the x-axis VS the 1st column graphed on the y-axis
# 2. Row 2 is two subplots (a scatterplot and a line graph) of the 3rd column (x-axis) VS the 2nd column (y-axis)
# 3. Row 3 is two subplots (a scatterplot and a line graph) of the 3rd column (x-axis) VS the 1st column (y-axis)
# 4. Include a title and axis labels for each subplot. You can refer to the 1st column as `X`, the 2nd as `Y`, and the 3rd as `Z`.
# 5. To insure there is enough space between subplots use [subplots_adjust](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots_adjust.html)

# %%
### BEGIN SOLUTION
fig, axes = plt.subplots(3, 2, figsize=(12, 12))
# Row 1: x = 2nd column (index 1), y = 1st column (index 0)
x1 = mdata[:, 1]; y1 = mdata[:, 0]
axes[0, 0].scatter(x1, y1, c='b', label='scatter')
axes[0, 0].set(title='Y vs X (scatter): 1st vs 2nd', xlabel='2nd column (X)', ylabel='1st column (Y)')
axes[0, 0].legend()
axes[0, 1].plot(x1, y1, 'r-', label='line')
axes[0, 1].set(title='Y vs X (line): 1st vs 2nd', xlabel='2nd column (X)', ylabel='1st column (Y)')
axes[0, 1].legend()

# Row 2: x = 3rd column (index 2), y = 2nd column (index 1)
x2 = mdata[:, 2]; y2 = mdata[:, 1]
axes[1, 0].scatter(x2, y2, c='g', label='scatter')
axes[1, 0].set(title='Y vs X (scatter): 2nd vs 3rd', xlabel='3rd column (X)', ylabel='2nd column (Y)')
axes[1, 0].legend()
axes[1, 1].plot(x2, y2, 'm-', label='line')
axes[1, 1].set(title='Y vs X (line): 2nd vs 3rd', xlabel='3rd column (X)', ylabel='2nd column (Y)')
axes[1, 1].legend()

# Row 3: x = 3rd column (index 2), y = 1st column (index 0)
x3 = mdata[:, 2]; y3 = mdata[:, 0]
axes[2, 0].scatter(x3, y3, c='c', label='scatter')
axes[2, 0].set(title='Y vs X (scatter): 1st vs 3rd', xlabel='3rd column (X)', ylabel='1st column (Y)')
axes[2, 0].legend()
axes[2, 1].plot(x3, y3, 'k-', label='line')
axes[2, 1].set(title='Y vs X (line): 1st vs 3rd', xlabel='3rd column (X)', ylabel='1st column (Y)')
axes[2, 1].legend()

plt.subplots_adjust(hspace=0.45, wspace=0.3)
plt.show()
### END SOLUTION

# %% [markdown]
# ### 2c. Analysis Question
#
# **Question 1:** Which pairs of columns are easier to read as scatter plots and which are easier to read as line graphs? Why?

# %% [markdown]
# **Answer 1:**
# 1st vs 2nd and 1st vs 3rd pairs is easier to read as scatter plots, The points form a loose cloud with no obvious single curve, and it's easy to judge correlation, spread, and outliers immediately. The 2nd vs 3rd columns are easier to read as a line graph because the line reveals a smooth and repeating wave, which suggests a continuous relationship where nearby x values produce nearby y values.

# %% [markdown]
# ## Task 3: Submit the Lab on Google Classroom
#
# Follow the expected lab submission instructions on the lab website.
